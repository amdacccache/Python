# %%
'''
Anna Daccache
10/7/19
CS5001
Fall 2019
Homework 4
Letter Count
'''

a = 'a'
b = 'b'
c = 'c'
d = 'd'
e = 'e'
f = 'f'
g = 'g'
h = 'h'
i = 'i'
j = 'j'
k = 'k'
l = 'l'
m = 'm'
n = 'n'
o = 'o'
p = 'p'
q = 'q'
r = 'r'
s = 's'
t = 't'
u = 'u'
v = 'v'
w = 'w'
x = 'x'
y = 'y'
z = 'z'

def histogram(x):
    # assinging lower case value to the message
    lower_phrase = phrase.lower()
    # splitting up each word
    split_phrase = lower_phrase.split()
    # for loop iterating through the variables
    for letter in x:
        if letter not in split_phrase:
            split_phrase[i] = 1
        elif letter == a:
            split_phrase[i] += 1
        elif letter == b:
            split_phrase[i] += 1
        elif letter == c:
            split_phrase[i] += 1
        elif letter == d:
            split_phrase[i] += 1
        elif letter == e:
            split_phrase[i] += 1
        elif letter == f:
            split_phrase[i] += 1
        elif letter == g:
            split_phrase[i] += 1
        elif letter == h:
            split_phrase[i] += 1
        elif letter == i:
            split_phrase[i] += 1
        elif letter == j:
            split_phrase[i] += 1
        elif letter == k:
            split_phrase[i] += 1
        elif letter == l:
            split_phrase[i] += 1
        elif letter == m:
            split_phrase[i] += 1
        elif letter == n:
            split_phrase[i] += 1
        elif letter == o:
            split_phrase[i] += 1
        elif letter == p:
            split_phrase[i] += 1
        elif letter == q:
            split_phrase[i] += 1
        elif letter == r:
            split_phrase[i] += 1
        elif letter == s:
            split_phrase[i] += 1
        elif letter == t:
            split_phrase[i] += 1
        elif letter == u:
            split_phrase[i] += 1
        elif letter == v:
            split_phrase[i] += 1
        elif letter == w:
            split_phrase[i] += 1
        elif letter == x:
            split_phrase[i] += 1
        elif letter == y:
            split_phrase[i] += 1
        elif letter == z:
            split_phrase[i] += 1
    return split_phrase

# prompting user for their message
phrase = input('Type a message. ')
print(histogram(phrase))
